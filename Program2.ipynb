# %%
#2 pgrm
import tensorflow as tf
from tensorflow.keras import layers,models,optimizers
import numpy as np
import matplotlib.pyplot as plt

def create_data():
    X=np.random.randn(1000,10)
    y=np.random.randn(1000,1)
    return X,y

def create_model():
  model = models.Sequential([
      layers.Dense(50,activation='relu',input_shape=(10,)),
      layers.Dense(20,activation='relu'),
      layers.Dense(1)
  ])
  return model

def train_model(model,optimizer,X,y,batch_size,epochs,optimizer_name):
  model.compile(optimizer=optimizer,loss='mean_squared_error')
  history=[]

  for epoch in range(epochs):
    hist=model.fit(X,y,batch_size=batch_size,epochs=1,verbose=0)
    loss=hist.history['loss'][0]
    history.append(loss)
    print(f"Epoch {epoch+1}/{epochs}-{optimizer_name} Loss:{loss:4f}")
  return history

X,y=create_data()
model_sgd=create_model()
model_adam=create_model()
optimizer_sgd=optimizers.SGD(learning_rate=0.01)
optimizer_adam=optimizers.Adam(learning_rate=0.001)

epochs=50
batch_size=32

print("\nTraining with SGD Optimizer:")
sgd_loss=train_model(model_sgd,optimizer_sgd,X,y,batch_size,epochs,'SGD')

print("\nTraining with Adam Optimizer:")
adam_loss=train_model(model_adam,optimizer_adam,X,y,batch_size,epochs,'Adam')
plt.plot(range(1,epochs+1),sgd_loss,label='SGD',color='blue')
plt.plot(range(1,epochs+1),adam_loss,label='Adam',color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('SGD vs Adam Optimizer: Loss comparision')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\krish\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Training with SGD Optimizer:
# Epoch 1/50-SGD Loss:1.198774
# Epoch 2/50-SGD Loss:1.146622
# Epoch 3/50-SGD Loss:1.123094
# Epoch 4/50-SGD Loss:1.109628
# Epoch 5/50-SGD Loss:1.098895
# Epoch 6/50-SGD Loss:1.092158
# Epoch 7/50-SGD Loss:1.084885
# Epoch 8/50-SGD Loss:1.080062
# Epoch 9/50-SGD Loss:1.075387
# Epoch 10/50-SGD Loss:1.069268
# Epoch 11/50-SGD Loss:1.065211
# Epoch 12/50-SGD Loss:1.059447
# Epoch 13/50-SGD Loss:1.057809
# Epoch 14/50-SGD Loss:1.051320
# Epoch 15/50-SGD Loss:1.049467
# Epoch 16/50-SGD Loss:1.044765
# Epoch 17/50-SGD Loss:1.040602
# Epoch 18/50-SGD Loss:1.038166
# Epoch 19/50-SGD Loss:1.033788
# Epoch 20/50-SGD Loss:1.029173
# Epoch 21/50-SGD Loss:1.025330
# Epoch 22/50-SGD Loss:1.021639
# Epoch 23/50-SGD Loss:1.020384
# Epoch 24/50-SGD Loss:1.015865
# Epoch 25/50-SGD Loss:1.011919
# Epoch 26/50-SGD Loss:1.007992
# Epoch 27/50-SGD Loss:1.004460
# Epoch 28/50-SGD Loss:1.000830
# Epoch 29/50-SGD Loss:0.999396
# Epoch 30/50-SGD Loss:0.995783
# Epoch 31/50-SGD Loss:0.992057
# Epoch 32/50-SGD Loss:0.989267
# Epoch 33/50-SGD Loss:0.986261
# Epoch 34/50-SGD Loss:0.982533
# Epoch 35/50-SGD Loss:0.978659
# Epoch 36/50-SGD Loss:0.976557
# Epoch 37/50-SGD Loss:0.974373
# Epoch 38/50-SGD Loss:0.970796
# Epoch 39/50-SGD Loss:0.966356
# Epoch 40/50-SGD Loss:0.964250
# Epoch 41/50-SGD Loss:0.959039
# Epoch 42/50-SGD Loss:0.955077
# Epoch 43/50-SGD Loss:0.950329
# Epoch 44/50-SGD Loss:0.949345
# Epoch 45/50-SGD Loss:0.945297
# Epoch 46/50-SGD Loss:0.939917
# Epoch 47/50-SGD Loss:0.939269
# Epoch 48/50-SGD Loss:0.936494
# Epoch 49/50-SGD Loss:0.931707
# Epoch 50/50-SGD Loss:0.928174
#
# Training with Adam Optimizer:
# Epoch 1/50-Adam Loss:1.205128
# Epoch 2/50-Adam Loss:1.137032
# Epoch 3/50-Adam Loss:1.110630
# Epoch 4/50-Adam Loss:1.090260
# Epoch 5/50-Adam Loss:1.074876
# Epoch 6/50-Adam Loss:1.062665
# Epoch 7/50-Adam Loss:1.053730
# Epoch 8/50-Adam Loss:1.043376
# Epoch 9/50-Adam Loss:1.034290
# Epoch 10/50-Adam Loss:1.024715
# Epoch 11/50-Adam Loss:1.019697
# Epoch 12/50-Adam Loss:1.006177
# Epoch 13/50-Adam Loss:0.998598
# Epoch 14/50-Adam Loss:0.987611
# Epoch 15/50-Adam Loss:0.982284
# Epoch 16/50-Adam Loss:0.971931
# Epoch 17/50-Adam Loss:0.965858
# Epoch 18/50-Adam Loss:0.956440
# Epoch 19/50-Adam Loss:0.950978
# Epoch 20/50-Adam Loss:0.935894
# Epoch 21/50-Adam Loss:0.933937
# Epoch 22/50-Adam Loss:0.924016
# Epoch 23/50-Adam Loss:0.916846
# Epoch 24/50-Adam Loss:0.920126
# Epoch 25/50-Adam Loss:0.894781
# Epoch 26/50-Adam Loss:0.885711
# Epoch 27/50-Adam Loss:0.876166
# Epoch 28/50-Adam Loss:0.866423
# Epoch 29/50-Adam Loss:0.859913
# Epoch 30/50-Adam Loss:0.854900
# Epoch 31/50-Adam Loss:0.845900
# Epoch 32/50-Adam Loss:0.837492
# Epoch 33/50-Adam Loss:0.828538
# Epoch 34/50-Adam Loss:0.817971
# Epoch 35/50-Adam Loss:0.805670
# Epoch 36/50-Adam Loss:0.800535
# Epoch 37/50-Adam Loss:0.789662
# Epoch 38/50-Adam Loss:0.782296
# Epoch 39/50-Adam Loss:0.772936
# Epoch 40/50-Adam Loss:0.768922
# Epoch 41/50-Adam Loss:0.757269
# Epoch 42/50-Adam Loss:0.750970
# Epoch 43/50-Adam Loss:0.750880
# Epoch 44/50-Adam Loss:0.734260
# Epoch 45/50-Adam Loss:0.728731
# Epoch 46/50-Adam Loss:0.722716
# Epoch 47/50-Adam Loss:0.710635
# Epoch 48/50-Adam Loss:0.710853
# Epoch 49/50-Adam Loss:0.703589
# Epoch 50/50-Adam Loss:0.688135

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from keras import layers,models,optimizers

def create_data():
    X=np.random.randn(1000,10)
    y=np.random.randn(1000,1)
    return X,y

def create_model():
  model = models.Sequential([
      layers.Dense(200,activation='relu',input_shape=(10,)),
      layers.Dense(100,activation='tanh'),
      layers.Dense(50,activation='sigmoid'),
      layers.Dense(1)
  ])
  return model

def train_model(model,optimizer,X,y,batch_size,epochs,optimizer_name):
  model.compile(optimizer=optimizer,loss='mean_squared_error')
  history=[]

  for epoch in range(epochs):
    hist=model.fit(X,y,batch_size=batch_size,epochs=1,verbose=0)
    loss=hist.history['loss'][0]
    history.append(loss)
    print(f"Epoch {epoch+1}/{epochs}-{optimizer_name} Loss:{loss:4f}")
  return history

X,y = create_data()
model_sgd = create_model()
model_adam = create_model()
model_rmsprop = create_model()

optimizer_sgd = optimizers.SGD(learning_rate=0.05)
optimizer_adam = optimizers.Adam(learning_rate=0.001)
optimizer_rmsprop = optimizers.RMSprop(learning_rate=0.1)

epochs = 50
batch_size = 16

print("\nTraining with SGD Optimizer:")
sgd_loss = train_model(model_sgd, optimizer_sgd, X, y, batch_size, epochs, 'SGD')

print("\nTraining with Adam Optimizer:")
adam_loss = train_model(model_adam, optimizer_adam, X, y, batch_size, epochs, 'Adam')

print("\nTraining with RMSprop Optimizer:")
adaboost_loss = train_model(model_rmsprop, optimizer_rmsprop, X, y, batch_size, epochs, 'RMSprop')

plt.plot(range(1,epochs+1),sgd_loss,label='SGD',color='blue')
plt.plot(range(1,epochs+1),adam_loss,label='Adam',color='orange')
plt.plot(range(1,epochs+1),adaboost_loss,label='RMSprop',color='red')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss comparision')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\krish\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Training with SGD Optimizer:
# Epoch 1/50-SGD Loss:1.218074
# Epoch 2/50-SGD Loss:1.301574
# Epoch 3/50-SGD Loss:1.105946
# Epoch 4/50-SGD Loss:1.106525
# Epoch 5/50-SGD Loss:1.065132
# Epoch 6/50-SGD Loss:1.093017
# Epoch 7/50-SGD Loss:1.044610
# Epoch 8/50-SGD Loss:1.079839
# Epoch 9/50-SGD Loss:1.072076
# Epoch 10/50-SGD Loss:1.012944
# Epoch 11/50-SGD Loss:1.039551
# Epoch 12/50-SGD Loss:1.026557
# Epoch 13/50-SGD Loss:1.017274
# Epoch 14/50-SGD Loss:1.021103
# Epoch 15/50-SGD Loss:1.011196
# Epoch 16/50-SGD Loss:1.000477
# Epoch 17/50-SGD Loss:0.993439
# Epoch 18/50-SGD Loss:1.009853
# Epoch 19/50-SGD Loss:0.989439
# Epoch 20/50-SGD Loss:0.972113
# Epoch 21/50-SGD Loss:0.969247
# Epoch 22/50-SGD Loss:0.984225
# Epoch 23/50-SGD Loss:0.960235
# Epoch 24/50-SGD Loss:0.960587
# Epoch 25/50-SGD Loss:0.960970
# Epoch 26/50-SGD Loss:0.932899
# Epoch 27/50-SGD Loss:0.925077
# Epoch 28/50-SGD Loss:0.935056
# Epoch 29/50-SGD Loss:0.923924
# Epoch 30/50-SGD Loss:0.948228
# Epoch 31/50-SGD Loss:0.910635
# Epoch 32/50-SGD Loss:0.906747
# Epoch 33/50-SGD Loss:0.911220
# Epoch 34/50-SGD Loss:0.884921
# Epoch 35/50-SGD Loss:0.897639
# Epoch 36/50-SGD Loss:0.864296
# Epoch 37/50-SGD Loss:0.845835
# Epoch 38/50-SGD Loss:0.846087
# Epoch 39/50-SGD Loss:0.871019
# Epoch 40/50-SGD Loss:0.848758
# Epoch 41/50-SGD Loss:0.851060
# Epoch 42/50-SGD Loss:0.827556
# Epoch 43/50-SGD Loss:0.817492
# Epoch 44/50-SGD Loss:0.784157
# Epoch 45/50-SGD Loss:0.815286
# Epoch 46/50-SGD Loss:0.803416
# Epoch 47/50-SGD Loss:0.751782
# Epoch 48/50-SGD Loss:0.788257
# Epoch 49/50-SGD Loss:0.741582
# Epoch 50/50-SGD Loss:0.746453
#
# Training with Adam Optimizer:
# Epoch 1/50-Adam Loss:1.069925
# Epoch 2/50-Adam Loss:1.045066
# Epoch 3/50-Adam Loss:1.025956
# Epoch 4/50-Adam Loss:1.022655
# Epoch 5/50-Adam Loss:1.011120
# Epoch 6/50-Adam Loss:0.996822
# Epoch 7/50-Adam Loss:0.978771
# Epoch 8/50-Adam Loss:0.980004
# Epoch 9/50-Adam Loss:0.974882
# Epoch 10/50-Adam Loss:0.952003
# Epoch 11/50-Adam Loss:0.958469
# Epoch 12/50-Adam Loss:0.960205
# Epoch 13/50-Adam Loss:0.931070
# Epoch 14/50-Adam Loss:0.935564
# Epoch 15/50-Adam Loss:0.903560
# Epoch 16/50-Adam Loss:0.891007
# Epoch 17/50-Adam Loss:0.881459
# Epoch 18/50-Adam Loss:0.860079
# Epoch 19/50-Adam Loss:0.837681
# Epoch 20/50-Adam Loss:0.811189
# Epoch 21/50-Adam Loss:0.787179
# Epoch 22/50-Adam Loss:0.754312
# Epoch 23/50-Adam Loss:0.741445
# Epoch 24/50-Adam Loss:0.722216
# Epoch 25/50-Adam Loss:0.702838
# Epoch 26/50-Adam Loss:0.638205
# Epoch 27/50-Adam Loss:0.628406
# Epoch 28/50-Adam Loss:0.540247
# Epoch 29/50-Adam Loss:0.540337
# Epoch 30/50-Adam Loss:0.531662
# Epoch 31/50-Adam Loss:0.473046
# Epoch 32/50-Adam Loss:0.516165
# Epoch 33/50-Adam Loss:0.447294
# Epoch 34/50-Adam Loss:0.424642
# Epoch 35/50-Adam Loss:0.417186
# Epoch 36/50-Adam Loss:0.422996
# Epoch 37/50-Adam Loss:0.359061
# Epoch 38/50-Adam Loss:0.334969
# Epoch 39/50-Adam Loss:0.388315
# Epoch 40/50-Adam Loss:0.332754
# Epoch 41/50-Adam Loss:0.305610
# Epoch 42/50-Adam Loss:0.306627
# Epoch 43/50-Adam Loss:0.300266
# Epoch 44/50-Adam Loss:0.325083
# Epoch 45/50-Adam Loss:0.303029
# Epoch 46/50-Adam Loss:0.264533
# Epoch 47/50-Adam Loss:0.313218
# Epoch 48/50-Adam Loss:0.266396
# Epoch 49/50-Adam Loss:0.261776
# Epoch 50/50-Adam Loss:0.226559
#
# Training with RMSprop Optimizer:
# Epoch 1/50-RMSprop Loss:2.150187
# Epoch 2/50-RMSprop Loss:1.152050
# Epoch 3/50-RMSprop Loss:1.111407
# Epoch 4/50-RMSprop Loss:1.141480
# Epoch 5/50-RMSprop Loss:1.182764
# Epoch 6/50-RMSprop Loss:1.159135
# Epoch 7/50-RMSprop Loss:1.142033
# Epoch 8/50-RMSprop Loss:1.170837
# Epoch 9/50-RMSprop Loss:1.206116
# Epoch 10/50-RMSprop Loss:1.170444
# Epoch 11/50-RMSprop Loss:1.166230
# Epoch 12/50-RMSprop Loss:1.170305
# Epoch 13/50-RMSprop Loss:1.207163
# Epoch 14/50-RMSprop Loss:1.177343
# Epoch 15/50-RMSprop Loss:1.196721
# Epoch 16/50-RMSprop Loss:1.185881
# Epoch 17/50-RMSprop Loss:1.179410
# Epoch 18/50-RMSprop Loss:1.149791
# Epoch 19/50-RMSprop Loss:1.191885
# Epoch 20/50-RMSprop Loss:1.214700
# Epoch 21/50-RMSprop Loss:1.159837
# Epoch 22/50-RMSprop Loss:1.179603
# Epoch 23/50-RMSprop Loss:1.191617
# Epoch 24/50-RMSprop Loss:1.148839
# Epoch 25/50-RMSprop Loss:1.195840
# Epoch 26/50-RMSprop Loss:1.163207
# Epoch 27/50-RMSprop Loss:1.196113
# Epoch 28/50-RMSprop Loss:1.173780
# Epoch 29/50-RMSprop Loss:1.176584
# Epoch 30/50-RMSprop Loss:1.231479
# Epoch 31/50-RMSprop Loss:1.192651
# Epoch 32/50-RMSprop Loss:1.220060
# Epoch 33/50-RMSprop Loss:1.241471
# Epoch 34/50-RMSprop Loss:1.220722
# Epoch 35/50-RMSprop Loss:1.216905
# Epoch 36/50-RMSprop Loss:1.214669
# Epoch 37/50-RMSprop Loss:1.195638
# Epoch 38/50-RMSprop Loss:1.220936
# Epoch 39/50-RMSprop Loss:1.197713
# Epoch 40/50-RMSprop Loss:1.213009
# Epoch 41/50-RMSprop Loss:1.237284
# Epoch 42/50-RMSprop Loss:1.167465
# Epoch 43/50-RMSprop Loss:1.215284
# Epoch 44/50-RMSprop Loss:1.190057
# Epoch 45/50-RMSprop Loss:1.213640
# Epoch 46/50-RMSprop Loss:1.242343
# Epoch 47/50-RMSprop Loss:1.227249
# Epoch 48/50-RMSprop Loss:1.250870
# Epoch 49/50-RMSprop Loss:1.228134
# Epoch 50/50-RMSprop Loss:1.221782
