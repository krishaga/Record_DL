# %%
import numpy as np

def unitStep(v):
    return 1 if v >= 0 else 0

def perceptronModel(x, w, b):
    v = np.dot(w, x) + b
    y = unitStep(v)
    return y

def NOT_logicFunction(x):
    wNOT = -1
    bNOT = 0.5
    return perceptronModel(x, wNOT, bNOT)

def AND_logicFunction(x):
    w = np.array([1, 1])
    bAND = -1.5
    return perceptronModel(x, w, bAND)

def OR_logicFunction(x):
    w = np.array([1, 1])
    bOR = -0.5
    return perceptronModel(x, w, bOR)

def XOR_logicFunction(x):
    y1 = AND_logicFunction(x)
    y2 = OR_logicFunction(x)
    y3 = NOT_logicFunction(y1)
    final_x = np.array([y2, y3])
    finalOutput = AND_logicFunction(final_x)
    return finalOutput

def check_weights():
    test_cases = [
        (np.array([0, 0]), 0),
        (np.array([0, 1]), 1),
        (np.array([1, 0]), 1),
        (np.array([1, 1]), 0)
    ]
    
    weights_correct = True
    for x, expected in test_cases:
        result = XOR_logicFunction(x)
        if result != expected:
            weights_correct = False
            print(f"Weight or bias error for input {x}. Expected {expected}, got {result}.")
            update_weights()

    if weights_correct:
        print("All weights are correct!")

def update_weights():
    print("Updating weights and biases...")
test1 = np.array([0, 1])
test2 = np.array([1, 1])
test3 = np.array([0, 0])
test4 = np.array([1, 0])
print("XOR({}, {}) = {}".format(0, 1, XOR_logicFunction(test1)))
print("XOR({}, {}) = {}".format(1, 1, XOR_logicFunction(test2)))
print("XOR({}, {}) = {}".format(0, 0, XOR_logicFunction(test3)))
print("XOR({}, {}) = {}".format(1, 0, XOR_logicFunction(test4)))
check_weights()
# Out:
# XOR(0, 1) = 1
# XOR(1, 1) = 0
# XOR(0, 0) = 0
# XOR(1, 0) = 1
# All weights are correct!

# %%
import numpy as np
def unitStep(v):
    if v>=0:
        return 1
    else:
        return 0

def perceptronModel(x,w,b):
    v=np.dot(w,x)+b
    y=unitStep(v)
    return y

def NOT_logicFunction(x):
    wNOT= -1
    bNOT= 0.5
    return perceptronModel(x,wNOT,bNOT)

def AND_logicFunction(x):
    w=np.array([1,1])
    b=-1.5
    return perceptronModel(x,w,b)

def OR_logicFunction(x):
    w=np.array([1,1])
    bOR=-0.5
    return perceptronModel(x,w,bOR)

def XOR_logicFunction(x):
  y1=AND_logicFunction(x)
  y2=OR_logicFunction(x)
  y3=NOT_logicFunction(y1)
  final_x=np.array([y2,y3])
  finalOutput=AND_logicFunction(final_x)
  return finalOutput

test1=np.array([0,1])
test2=np.array([1,1])
test3=np.array([0,0])
test4=np.array([1,0])

print("XOR ({},{}) = {}".format(0,1,XOR_logicFunction(test1)))
print("XOR ({},{}) = {}".format(1,1,XOR_logicFunction(test2)))
print("XOR ({},{}) = {}".format(0,0,XOR_logicFunction(test3)))
print("XOR ({},{}) = {}".format(1,0,XOR_logicFunction(test4)))

# %%
import numpy as np

# Step function using lambda for conciseness
unitStep = lambda v: 1 if v >= 0 else 0

# Define the perceptron model function
def perceptronModel(x, w, b):
    v = np.dot(w, x) + b
    y = unitStep(v)
    return y

# Logic gate functions with weights and biases
def NOT_logicFunction(x):
    w_NOT = -1
    b_NOT = 0.5
    return perceptronModel(x, w_NOT, b_NOT)

def AND_logicFunction(x):
    w_AND = np.array([1, 1])
    b_AND = -1.5
    return perceptronModel(x, w_AND, b_AND)

def OR_logicFunction(x):
    w_OR = np.array([1, 1])
    b_OR = -0.5
    return perceptronModel(x, w_OR, b_OR)

def XOR_logicFunction(x):
    # Intermediate outputs
    y1 = AND_logicFunction(x)
    y2 = OR_logicFunction(x)
    y3 = NOT_logicFunction(y1)
    
    # Final output
    final_input = np.array([y2, y3])
    final_output = AND_logicFunction(final_input)
    return final_output

# Test cases
test_cases = [np.array([0, 1]), np.array([1, 1]), np.array([0, 0]), np.array([1, 0])]

# Testing XOR logic function with formatted output
for test in test_cases:
    print(f"XOR ({test[0]},{test[1]}) = {XOR_logicFunction(test)}")
# Out:
# XOR (0,1) = 1
# XOR (1,1) = 0
# XOR (0,0) = 0
# XOR (1,0) = 1
