# %%
#2 pgrm
import tensorflow as tf
from tensorflow.keras import layers,models,optimizers
import numpy as np
import matplotlib.pyplot as plt

def create_data():
    X=np.random.randn(1000,10)
    y=np.random.randn(1000,1)
    return X,y

def create_model():
  model = models.Sequential([
      layers.Dense(50,activation='relu',input_shape=(10,)),
      layers.Dense(20,activation='relu'),
      layers.Dense(1)
  ])
  return model

def train_model(model,optimizer,X,y,batch_size,epochs,optimizer_name):
  model.compile(optimizer=optimizer,loss='mean_squared_error')
  history=[]

  for epoch in range(epochs):
    hist=model.fit(X,y,batch_size=batch_size,epochs=1,verbose=0)
    loss=hist.history['loss'][0]
    history.append(loss)
    print(f"Epoch {epoch+1}/{epochs}-{optimizer_name} Loss:{loss:4f}")
  return history

X,y=create_data()
model_sgd=create_model()
model_adam=create_model()
optimizer_sgd=optimizers.SGD(learning_rate=0.01)
optimizer_adam=optimizers.Adam(learning_rate=0.001)

epochs=50
batch_size=32

print("\nTraining with SGD Optimizer:")
sgd_loss=train_model(model_sgd,optimizer_sgd,X,y,batch_size,epochs,'SGD')

print("\nTraining with Adam Optimizer:")
adam_loss=train_model(model_adam,optimizer_adam,X,y,batch_size,epochs,'Adam')
plt.plot(range(1,epochs+1),sgd_loss,label='SGD',color='blue')
plt.plot(range(1,epochs+1),adam_loss,label='Adam',color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('SGD vs Adam Optimizer: Loss comparision')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\krish\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Training with SGD Optimizer:
# Epoch 1/50-SGD Loss:1.162038
# Epoch 2/50-SGD Loss:1.049430
# Epoch 3/50-SGD Loss:1.017564
# Epoch 4/50-SGD Loss:1.000449
# Epoch 5/50-SGD Loss:0.991370
# Epoch 6/50-SGD Loss:0.982893
# Epoch 7/50-SGD Loss:0.975958
# Epoch 8/50-SGD Loss:0.969953
# Epoch 9/50-SGD Loss:0.965399
# Epoch 10/50-SGD Loss:0.960532
# Epoch 11/50-SGD Loss:0.956016
# Epoch 12/50-SGD Loss:0.953216
# Epoch 13/50-SGD Loss:0.948901
# Epoch 14/50-SGD Loss:0.945490
# Epoch 15/50-SGD Loss:0.940683
# Epoch 16/50-SGD Loss:0.937727
# Epoch 17/50-SGD Loss:0.933841
# Epoch 18/50-SGD Loss:0.930221
# Epoch 19/50-SGD Loss:0.928748
# Epoch 20/50-SGD Loss:0.925048
# Epoch 21/50-SGD Loss:0.921261
# Epoch 22/50-SGD Loss:0.919283
# Epoch 23/50-SGD Loss:0.915541
# Epoch 24/50-SGD Loss:0.912500
# Epoch 25/50-SGD Loss:0.909894
# Epoch 26/50-SGD Loss:0.909230
# Epoch 27/50-SGD Loss:0.902720
# Epoch 28/50-SGD Loss:0.903277
# Epoch 29/50-SGD Loss:0.898854
# Epoch 30/50-SGD Loss:0.897115
# Epoch 31/50-SGD Loss:0.893020
# Epoch 32/50-SGD Loss:0.891223
# Epoch 33/50-SGD Loss:0.888056
# Epoch 34/50-SGD Loss:0.886632
# Epoch 35/50-SGD Loss:0.882669
# Epoch 36/50-SGD Loss:0.878349
# Epoch 37/50-SGD Loss:0.877898
# Epoch 38/50-SGD Loss:0.874503
# Epoch 39/50-SGD Loss:0.872058
# Epoch 40/50-SGD Loss:0.871182
# Epoch 41/50-SGD Loss:0.867279
# Epoch 42/50-SGD Loss:0.863917
# Epoch 43/50-SGD Loss:0.860602
# Epoch 44/50-SGD Loss:0.859512
# Epoch 45/50-SGD Loss:0.856223
# Epoch 46/50-SGD Loss:0.850433
# Epoch 47/50-SGD Loss:0.850959
# Epoch 48/50-SGD Loss:0.843864
# Epoch 49/50-SGD Loss:0.845994
# Epoch 50/50-SGD Loss:0.838307
#
# Training with Adam Optimizer:
# Epoch 1/50-Adam Loss:1.108737
# Epoch 2/50-Adam Loss:1.012942
# Epoch 3/50-Adam Loss:0.988200
# Epoch 4/50-Adam Loss:0.973802
# Epoch 5/50-Adam Loss:0.960524
# Epoch 6/50-Adam Loss:0.948555
# Epoch 7/50-Adam Loss:0.938604
# Epoch 8/50-Adam Loss:0.930821
# Epoch 9/50-Adam Loss:0.918509
# Epoch 10/50-Adam Loss:0.910912
# Epoch 11/50-Adam Loss:0.905663
# Epoch 12/50-Adam Loss:0.896553
# Epoch 13/50-Adam Loss:0.887920
# Epoch 14/50-Adam Loss:0.880250
# Epoch 15/50-Adam Loss:0.874747
# Epoch 16/50-Adam Loss:0.871344
# Epoch 17/50-Adam Loss:0.859947
# Epoch 18/50-Adam Loss:0.854240
# Epoch 19/50-Adam Loss:0.845052
# Epoch 20/50-Adam Loss:0.838139
# Epoch 21/50-Adam Loss:0.829409
# Epoch 22/50-Adam Loss:0.826745
# Epoch 23/50-Adam Loss:0.819142
# Epoch 24/50-Adam Loss:0.814297
# Epoch 25/50-Adam Loss:0.803647
# Epoch 26/50-Adam Loss:0.797421
# Epoch 27/50-Adam Loss:0.791633
# Epoch 28/50-Adam Loss:0.786837
# Epoch 29/50-Adam Loss:0.782162
# Epoch 30/50-Adam Loss:0.768472
# Epoch 31/50-Adam Loss:0.764722
# Epoch 32/50-Adam Loss:0.763373
# Epoch 33/50-Adam Loss:0.751519
# Epoch 34/50-Adam Loss:0.742611
# Epoch 35/50-Adam Loss:0.734513
# Epoch 36/50-Adam Loss:0.727322
# Epoch 37/50-Adam Loss:0.721630
# Epoch 38/50-Adam Loss:0.724017
# Epoch 39/50-Adam Loss:0.711795
# Epoch 40/50-Adam Loss:0.710604
# Epoch 41/50-Adam Loss:0.692145
# Epoch 42/50-Adam Loss:0.691061
# Epoch 43/50-Adam Loss:0.693675
# Epoch 44/50-Adam Loss:0.678368
# Epoch 45/50-Adam Loss:0.669279
# Epoch 46/50-Adam Loss:0.668064
# Epoch 47/50-Adam Loss:0.658747
# Epoch 48/50-Adam Loss:0.657342
# Epoch 49/50-Adam Loss:0.651857
# Epoch 50/50-Adam Loss:0.646748
